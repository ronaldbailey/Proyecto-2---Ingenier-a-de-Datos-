# %%
! git fetch
! git merge
! git add .
! git commit -m "verificacion  Rene"
! git push
# Out:
# Already up to date.
# [main a275190] verificacion  Rene
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 Desarrollo_Rene.ipynb
# remote: Resolving deltas:   0% (0/1)
# remote: Resolving deltas: 100% (1/1)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/ronaldbailey/Proyecto-2---Ingenier-a-de-Datos-.git
#    52ea221..a275190  main -> main

# %% [markdown]
# ### Descripción
#
# ### Scope
#
# El scope del proyecto toma datos de una empresa la cual se encarga de la confeccion de productos de tela ya sea de ropa como de productos de uso multiple (manteles entre otros). Lo que abarca en si seria la base de datos de clientes, vendedores y operaciones hechas por la empresa mencionada anteriormente.
#
# Se cita comentario: #datos ingresados son reales, solo el numero de factura o recibo no se contaba con el, por lo que se coloco uno para posteriormente ya llenarlo con datos reales al usar el codigo.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# El data frame de la libreria Pandas muestra los datos de la manera adecuada y trabajarlos utilizando fuentes de archivos en formato .CSV
#
# Para su manejo utilizamos propiedades de conexión de base de datos por medio de un servidor AWS que sirva como el servidor de base de datos y que en python pueda ser utilizada la data para el analisis del mismo.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Vemos los datos de la siguiente forma:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Exploración de datos
#
# Para la exploracion de datos primero tuvimos que instalar las librerias que nos servirian para la funcionalidad de las mismas. Las antes mencionadas serian las siguientes:
#
# pandas as pd
# numpy as np
# boto3
# psycopg2
# configparser
# matplotlib.pyplot as plt
# pymysql
# sqlalchemy
# openpyxl
#
# Todas utilizadas e instaladas por medio del comando pip. Se muestra un ejemplo de lo descrito anteriormente:
#
# pip install pymysql
#
# Visualizando los datos pudimos determinar ciertas conclusiones, la forma en la cual pudimos hacer esa exploración fue la siguiente:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ha estos datos le agregamos una grafica de dispersion con la cual pudimos ver que tanto se relacionaban entre si:

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ### Modelo de datos
#
# En el modelo de datos se decidio utilizar un Data Lake, ya que esta permite utilizar los datos de manera mas flexible. Dado que la forma en la que los datos se muestran dentro de las fuentes de datos de la empresa se ven de la manera en que vimos en la exploracion, se determinó que esa seria la mejor forma.

# %% [markdown]
# Estos son los motivos por los cuales nos decidimos por este modelo:
#
# - Flexibilidad: Un Data Lake permite almacenar todo tipo de datos en su formato original, sin necesidad de transformarlos previamente. Esto significa que puede manejar una gran variedad de datos, incluyendo datos estructurados, no estructurados y semiestructurados. Además, el almacenamiento de datos en bruto permite que los datos puedan ser transformados y utilizados de diferentes maneras en el futuro.
#
# - Escalabilidad: El Data Lake es altamente escalable y puede manejar grandes cantidades de datos. Con el crecimiento de la cantidad de datos, el Data Lake puede aumentar la capacidad de almacenamiento de manera efectiva, sin requerir modificaciones significativas.
#
# - Costo: El Data Lake es más económico que el Data Warehouse, ya que se utiliza un almacenamiento de bajo costo como Hadoop Distributed File System (HDFS) o Amazon S3 para almacenar los datos, en lugar de utilizar una base de datos relacional costosa.
#
# - Análisis avanzado: El Data Lake permite aplicar técnicas de análisis avanzado como el machine learning y el procesamiento de lenguaje natural en los datos sin la necesidad de migrar o transformar los datos.

# %% [markdown]
# Aqui vemos el proceso de la transformacion de los datos:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# El proceso del ETL es el siguiente código:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
