# %%
print("hola mundo")
# Out:
# hola mundo

# %%
! git add .

# %%
! git commit -m "primer commit DG"
! git push
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# To https://github.com/ronaldbailey/Proyecto-2---Ingenier-a-de-Datos-.git
#    5c2e815..15fdd4d  main -> main

# %% [markdown]
# ## Instalando bibliotecas necesarias

# %%
! pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-1.24.2-cp311-cp311-win_amd64.whl (14.8 MB)
#      ---------------------------------------- 14.8/14.8 MB 3.2 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-1.24.2
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.0.0-cp311-cp311-win_amd64.whl (11.2 MB)
#      ---------------------------------------- 11.2/11.2 MB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ------------------------------------ 502.3/502.3 kB 750.2 kB/s eta 0:00:00
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ------------------------------------- 341.8/341.8 kB 98.7 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: six>=1.5 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.0.0 pytz-2023.3 tzdata-2023.3
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.26.109-py3-none-any.whl (135 kB)
#      ------------------------------------ 135.6/135.6 kB 382.2 kB/s eta 0:00:00
# Collecting botocore<1.30.0,>=1.29.109
#   Downloading botocore-1.29.109-py3-none-any.whl (10.6 MB)
#      ---------------------------------------- 10.6/10.6 MB 3.2 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ---------------------------------------- 79.6/79.6 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from botocore<1.30.0,>=1.29.109->boto3) (2.8.2)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
#      -------------------------------------- 140.9/140.9 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.30.0,>=1.29.109->boto3) (1.16.0)
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.26.109 botocore-1.29.109 jmespath-1.0.1 s3transfer-0.6.0 urllib3-1.26.15
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading psycopg2-2.9.6-cp311-cp311-win_amd64.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 2.2 MB/s eta 0:00:00
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.6
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install configparser
# Out:
# Collecting configparser
#   Downloading configparser-5.3.0-py3-none-any.whl (19 kB)
# Installing collected packages: configparser
# Successfully installed configparser-5.3.0
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! git fetch
! git merge
! git add .
! git commit -m "formato readme"
! git push
# Out:
# Already up to date.
# warning: in the working copy of 'Desarrollo_DG.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main 57efcce] formato readme
#  2 files changed, 61 insertions(+), 14 deletions(-)
# remote: Resolving deltas:   0% (0/3)
# remote: Resolving deltas:  33% (1/3)
# remote: Resolving deltas:  66% (2/3)
# remote: Resolving deltas: 100% (3/3)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/ronaldbailey/Proyecto-2---Ingenier-a-de-Datos-.git
#    a5da871..57efcce  main -> main

# %%
# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.0.3-py3-none-any.whl (43 kB)
#      -------------------------------------- 43.7/43.7 kB 429.5 kB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.3
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install sqlalchemy
# Out:
# Collecting sqlalchemy
#   Downloading SQLAlchemy-2.0.9-cp311-cp311-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 2.7 MB/s eta 0:00:00
# Collecting typing-extensions>=4.2.0
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-2.0.2-cp311-cp311-win_amd64.whl (192 kB)
#      -------------------------------------- 192.5/192.5 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: typing-extensions, greenlet, sqlalchemy
# Successfully installed greenlet-2.0.2 sqlalchemy-2.0.9 typing-extensions-4.5.0
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      -------------------------------------- 250.0/250.0 kB 1.0 MB/s eta 0:00:00
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Importando bibliotecas

# %%
import pandas as pd
import numpy as np
import boto3
import psycopg2
import configparser

# %%
DB_USER="admincuentas2"
DB_NAME="cuentas"
DB_PASSWORD="cuentas2admin2023"
DB_PORT=3306
DB_HOST="cuentas2.clptjw9nvvtu.us-east-1.rds.amazonaws.com"

mysql_driver = "mysql+pymysql://{}:{}@{}:{}/{}".format(DB_USER, DB_PASSWORD, DB_HOST, DB_PORT, DB_NAME)
print(mysql_driver)
# Out:
# mysql+pymysql://admincuentas2:cuentas2admin2023@cuentas2.clptjw9nvvtu.us-east-1.rds.amazonaws.com:3306/cuentas

# %%
data_tipo_transacciones = [
     {'id_tipo_transac': 85095, 'tipo_transaccion': 'Depóito'}, 
     {'id_tipo_transac': 85098, 'tipo_transaccion': 'Retiro'},
     {'id_tipo_transac': 85194, 'tipo_transaccion': 'Transferencia'},
     {'id_tipo_transac': 85133, 'tipo_transaccion': 'Pago Prestamo'}
]
print(data_tipo_transacciones)
# Out:
# [{'id_tipo_transac': 85095, 'tipo_transaccion': 'Depóito'}, {'id_tipo_transac': 85098, 'tipo_transaccion': 'Retiro'}, {'id_tipo_transac': 85194, 'tipo_transaccion': 'Transferencia'}, {'id_tipo_transac': 85133, 'tipo_transaccion': 'Pago Prestamo'}]

# %%
df_transaccion = pd.DataFrame(data_tipo_transacciones)
df_transaccion
# Out:
#    id_tipo_transac tipo_transaccion
# 0            85095          Depóito
# 1            85098           Retiro
# 2            85194    Transferencia
# 3            85133    Pago Prestamo

# %%
response = df_transaccion.to_sql('tipo_transacciones',mysql_driver,index = False, if_exists ='append')
response
# Out:
# 4

# %%
! git fetch
! git merge
! git add .
! git commit -m "prueba de subida datos aws/mysql/visual"
! git push
# Out:
# Already up to date.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
datos_crudos = pd.read_csv('../datos/cxc_cxp_bancos_el_rosario.csv',encoding= 'utf8')

datos_crudos
# Out:
#     Codigo_Cuenta                    Cliente       Descripcion_Producto
# 0               1            Xenturi Global                   manteles   \
# 1               2            Xenturi Global                      polos
# 2               3                     ALTSA      150 gorras chiquimulja
# 3               4                Indellantas     200 gorras P.P. Cabal
# 4               5                Bobalicius              polos blancas
# 5               6           Profesor Abraham          camisas formales
# 6               7       Colegio Santa Marta           camisas formales
# 7               8              interconsumo          chumpas y camisas
# 8               9   colegio peque;os angeles                     polos
# 9              10             sennsa Studio           filipinas negras
# 10             11                yummy food                      polos
# 11             12  Policia Militar 2 brigada                    gorras
# 12             13                fricsergua                      polos
# 13             14                  El Rodeo   confeccion polos servicio
# 14             15                      UNBO            SERIGRAFIAS PNC
# 15             16                      UNBO               BORDADOS PNC
# 16             17       Servicios Manducare           camisas formales
# 17             18        Recursos del Golfo                      polos
# 18             19               Casa blanca                  uniformes
# 19             20             Hector Bistro                      polos
# 20             21               Arbol verde          chumpas de diario
# 21             22       Don Manuel Columbias              13 columbias
# 22             23             Pollo Campero      32 gorras papas pollo
# 23             24                   Blessco                   playeras
# 24             25     Cahabon escuela Arjona          camisas formales
# 25             26             Pollo Campero      camisas mantenimiento
# 26             27               Grupo Rolsa        Camisas manga larga
# 27             28             Pollo Campero               26 columbias
# 28             29               Grupo Rolsa        camisas con broches
# 29             30                     Trixo      pedido completo abirl
# 30             31              david Guzman        bordados en prendas
# 31             32               La estancia          uniformes febrero
# 32             33             Pollo Campero   columbias tela importada
# 33             34             Pollo Campero     columbias tela nacional
# 34             35               Grupo Rolsa              camisas ADESA
# 35             36       Transportes del Sol            camisas del sol
# 36             37                     Z Gas          1900 gorras marzo
# 37             38                       KIA         300 gorras febrero
# 38             39            Eventos Shadai        camisas polo grises
# 39             40                Il Pecieri             filipinas chef
# 40             41              David Guzman        Confeccion Columbias
# 41             42                   AMSTAFF                      gorras
# 42             43                     ALOHA         playeras y mochilas
# 43             44                     DAITOM             primer pedido
# 44             45                     UPANA          camisas columbias
# 45             46                    DAITOM                pedido extra
# 46             47             Pollo Campero        gorras mantenimiento
# 47             48    General Safety Bordados                  bordados
# 48             49                Agrosafari              camisas extras
# 49             50           Bejo Cancelacion         camisas columbias
# 50             51                     Z gas   1900 gorras entrega abril
#
#     Retencion Bien_o_Servicio    Factura _o_Recibo    Total_Pagar
# 0           0            Bien    64854FSEGS3182FS81    Q2,890.00   \
# 1           0            Bien    64854FSEGS3182FS92    Q3,260.00
# 2           0            Bien   64854FSEGS3182FS103    Q1,650.00
# 3           0            Bien   64854FSEGS3182FS114    Q2,000.00
# 4           0            Bien   64854FSEGS3182FS125      Q900.00
# 5           0            Bien   64854FSEGS3182FS136    Q3,105.00
# 6           0            Bien   64854FSEGS3182FS147    Q1,000.00
# 7           0            Bien   64854FSEGS3182FS158    Q1,845.00
# 8           0            Bien   64854FSEGS3182FS169    Q1,300.00
# 9           0            Bien  64854FSEGS3182FS1710    Q3,240.00
# 10          0            Bien  64854FSEGS3182FS1811    Q1,140.00
# 11          0            Bien  64854FSEGS3182FS1912    Q3,775.00
# 12          0            Bien  64854FSEGS3182FS2013    Q1,620.00
# 13        123        Servicio  64854FSEGS3182FS2114    Q2,460.00
# 14         75        Servicio  64854FSEGS3182FS2215    Q1,500.00
# 15   Q406.25         Servicio  64854FSEGS3182FS2316    Q8,125.00
# 16          0            Bien  64854FSEGS3182FS2417      Q542.50
# 17          0            Bien  64854FSEGS3182FS2518    Q1,975.00
# 18          0            Bien  64854FSEGS3182FS2619   Q23,783.00
# 19          0            Bien  64854FSEGS3182FS2720    Q1,012.50
# 20          0            Bien  64854FSEGS3182FS2821    Q2,907.50
# 21          0            Bien  64854FSEGS3182FS2922    Q1,755.00
# 22        120            Bien  64854FSEGS3182FS3023    Q2,400.00
# 23          0            Bien  64854FSEGS3182FS3124    Q1,550.00
# 24          0            Bien  64854FSEGS3182FS3225    Q6,520.00
# 25          0            Bien  64854FSEGS3182FS3326    Q3,025.00
# 26      462.4            Bien  64854FSEGS3182FS3427    Q9,248.00
# 27          0            Bien  64854FSEGS3182FS3528    Q6,370.00
# 28          0            Bien  64854FSEGS3182FS3629    Q3,776.00
# 29          0            Bien  64854FSEGS3182FS3730    Q9,968.50
# 30          0        Servicio  64854FSEGS3182FS3831    Q5,885.00
# 31          0            Bien  64854FSEGS3182FS3932   Q16,068.00
# 32          0            Bien  64854FSEGS3182FS4033    Q3,574.00
# 33          0            Bien  64854FSEGS3182FS4134    Q1,470.00
# 34          0            Bien  64854FSEGS3182FS4235    Q3,750.00
# 35          0            Bien  64854FSEGS3182FS4336    Q6,300.00
# 36  450.36175            Bien  64854FSEGS3182FS4437   Q28,025.00
# 37     91.599            Bien  64854FSEGS3182FS4538    Q5,700.00
# 38          0            Bien  64854FSEGS3182FS4639    Q4,190.00
# 39          0            Bien  64854FSEGS3182FS4740    Q2,500.00
# 40          0        Servicio  64854FSEGS3182FS4841   Q15,960.00
# 41          0            Bien  64854FSEGS3182FS4942    Q4,500.00
# 42          0            Bien  64854FSEGS3182FS5043    Q7,920.00
# 43          0            Bien  64854FSEGS3182FS5144    Q3,725.00
# 44          0            Bien  64854FSEGS3182FS5245    Q5,335.00
# 45          0            Bien  64854FSEGS3182FS5346    Q3,537.00
# 46          0            Bien  64854FSEGS3182FS5447      Q900.00
# 47          0            Bien  64854FSEGS3182FS5548      Q884.00
# 48          0            Bien  64854FSEGS3182FS5649      Q542.50
# 49  139.69651            Bien  64854FSEGS3182FS5750    Q8,693.00
# 50          0            Bien  64854FSEGS3182FS5851   Q28,025.00
#
#       Impuesto   Total_Libre  Fecha_Estm_Pago           tipo_cuenta
# 0      Q332.48     Q2,557.52       15/04/2023                 libre
# 1      Q375.04     Q2,884.96       15/04/2023                 libre
# 2      Q189.82     Q1,460.18       12/04/2023                 libre
# 3      Q230.09     Q1,769.91       13/04/2023                 libre
# 4      Q103.54       Q796.46       18/04/2023                 libre
# 5      Q357.21     Q2,747.79       15/04/2023                 libre
# 6      Q115.04       Q884.96       15/04/2023                 libre
# 7      Q212.26     Q1,632.74       12/04/2023                 libre
# 8      Q149.56     Q1,150.44       13/04/2023                 libre
# 9      Q372.74     Q2,867.26       18/04/2023                 libre
# 10     Q131.15     Q1,008.85       15/04/2023                 libre
# 11     Q434.29     Q3,340.71       25/08/2023                 libre
# 12     Q186.37     Q1,433.63       13/04/2023                 libre
# 13     Q283.01     Q2,176.99       18/04/2023                 libre
# 14     Q172.57     Q1,327.43       15/04/2023                 libre
# 15     Q934.73     Q7,190.27       25/08/2023                 libre
# 16      Q62.41       Q480.09       13/04/2023                 libre
# 17     Q227.21     Q1,747.79       18/04/2023                 libre
# 18   Q2,736.10    Q21,046.90       15/04/2023                 libre
# 19     Q116.48       Q896.02       15/04/2023                 libre
# 20     Q334.49     Q2,573.01       12/04/2023                 libre
# 21     Q201.90     Q1,553.10       13/04/2023                 libre
# 22     Q276.11     Q2,123.89       18/04/2023                 libre
# 23     Q178.32     Q1,371.68       15/04/2023                 libre
# 24     Q750.09     Q5,769.91       15/04/2023                 libre
# 25     Q348.01     Q2,676.99       12/04/2023                 libre
# 26   Q1,063.93     Q8,184.07       13/04/2023                 libre
# 27     Q732.83     Q5,637.17       18/04/2023                 libre
# 28     Q434.41     Q3,341.59       15/04/2023                 libre
# 29   Q1,146.82     Q8,821.68       25/08/2023                 libre
# 30     Q677.04     Q5,207.96       13/04/2023  extrafinanciamiento
# 31   Q1,848.53    Q14,219.47       18/04/2023  extrafinanciamiento
# 32     Q411.17     Q3,162.83       15/04/2023  extrafinanciamiento
# 33     Q169.12     Q1,300.88       25/08/2023  extrafinanciamiento
# 34     Q431.42     Q3,318.58       13/04/2023  extrafinanciamiento
# 35     Q724.78     Q5,575.22       07/04/2023  extrafinanciamiento
# 36   Q3,224.12    Q24,800.88       08/04/2023  extrafinanciamiento
# 37     Q655.75     Q5,044.25       01/04/2023  extrafinanciamiento
# 38     Q482.04     Q3,707.96       16/04/2023  extrafinanciamiento
# 39     Q287.61     Q2,212.39       25/08/2023  extrafinanciamiento
# 40   Q1,836.11    Q14,123.89       13/04/2023               capital
# 41     Q517.70     Q3,982.30       07/04/2023               capital
# 42     Q911.15     Q7,008.85       08/04/2023               capital
# 43     Q428.54     Q3,296.46       01/04/2023               capital
# 44     Q613.76     Q4,721.24       16/04/2023               capital
# 45     Q406.91     Q3,130.09       18/04/2023               capital
# 46     Q103.54       Q796.46       15/04/2023               capital
# 47     Q101.70       Q782.30       25/08/2023               capital
# 48      Q62.41       Q480.09       13/04/2023               capital
# 49   Q1,000.08     Q7,692.92       20/04/2023               capital
# 50   Q3,224.12    Q24,800.88       23/04/2023               capital

# %%
# Insertar los datos en la tabla MySQL
datos_crudos.to_sql(name='nombre_tabla', con=mysql_driver, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\sqlalchemy\engine\default.py:748, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     747 def do_execute(self, cursor, statement, parameters, context=None):
# --> 748     cursor.execute(statement, parameters)
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pymysql\cursors.py:158, in Cursor.execute(self, query, args)
#     156 query = self.mogrify(query, args)
# --> 158 result = self._query(query)
#     159 self._executed = query
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pymysql\cursors.py:325, in Cursor._query(self, q)
#     324 self._clear_result()
# --> 325 conn.query(q)
#     326 self._do_get_result()
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pymysql\connections.py:549, in Connection.query(self, sql, unbuffered)
#     548 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 549 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     550 return self._affected_rows
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pymysql\connections.py:779, in Connection._read_query_result(self, unbuffered)
#     778     result = MySQLResult(self)
# --> 779     result.read()
#     780 self._result = result
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pymysql\connections.py:1157, in MySQLResult.read(self)
#    1156 try:
# -> 1157     first_packet = self.connection._read_packet()
#    1159     if first_packet.is_ok_packet():
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pymysql\connections.py:729, in Connection._read_packet(self, packet_type)
#     728         self._result.unbuffered_active = False
# --> 729     packet.raise_for_error()
#     730 return packet
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# ProgrammingError: (1166, "Incorrect column name 'Factura _o_Recibo '")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[74], line 2
#       1 # Insertar los datos en la tabla MySQL
# ----> 2 datos_crudos.to_sql(name='nombre_tabla', con=mysql_driver, if_exists='replace', index=False)
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pandas\core\generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pandas\io\sql.py:767, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     762     raise NotImplementedError(
#     763         "'frame' argument should be either a Series or a DataFrame"
#     764     )
#     766 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 767     return pandas_sql.to_sql(
#     768         frame,
#     769         name,
#     770         if_exists=if_exists,
#     771         index=index,
#     772         index_label=index_label,
#     773         schema=schema,
#     774         chunksize=chunksize,
#     775         dtype=dtype,
#     776         method=method,
#     777         engine=engine,
#     778         **engine_kwargs,
#     779     )
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pandas\io\sql.py:1908, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1858 """
#    1859 Write records stored in a DataFrame to a SQL database.
#    1860
#    (...)
#    1904     Any additional kwargs are passed to the engine.
#    1905 """
#    1906 sql_engine = get_engine(engine)
# -> 1908 table = self.prep_table(
#    1909     frame=frame,
#    1910     name=name,
#    1911     if_exists=if_exists,
#    1912     index=index,
#    1913     index_label=index_label,
#    1914     schema=schema,
#    1915     dtype=dtype,
#    1916 )
#    1918 total_inserted = sql_engine.insert_records(
#    1919     table=table,
#    1920     con=self.con,
#    (...)
#    1927     **engine_kwargs,
#    1928 )
#    1930 self.check_case_sensitive(name=name, schema=schema)
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pandas\io\sql.py:1812, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1800             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1802 table = SQLTable(
#    1803     name,
#    1804     self,
#    (...)
#    1810     dtype=dtype,
#    1811 )
# -> 1812 table.create()
#    1813 return table
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pandas\io\sql.py:912, in SQLTable.create(self)
#     910         raise ValueError(f"'{self.if_exists}' is not valid for if_exists")
#     911 else:
# --> 912     self._execute_create()
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pandas\io\sql.py:898, in SQLTable._execute_create(self)
#     896 self.table = self.table.to_metadata(self.pd_sql.meta)
#     897 with self.pd_sql.run_transaction():
# --> 898     self.table.create(bind=self.pd_sql.con)
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\sqlalchemy\sql\schema.py:1149, in Table.create(self, bind, checkfirst)
#    1137 def create(self, bind: _CreateDropBind, checkfirst: bool = False) -> None:
#    1138     """Issue a ``CREATE`` statement for this
#    1139     :class:`_schema.Table`, using the given
#    1140     :class:`.Connection` or :class:`.Engine`
#    (...)
#    1146
#    1147     """
# -> 1149     bind._run_ddl_visitor(ddl.SchemaGenerator, self, checkfirst=checkfirst)
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\sqlalchemy\engine\base.py:2430, in Connection._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2418 def _run_ddl_visitor(
#    2419     self,
#    2420     visitorcallable: Type[Union[SchemaGenerator, SchemaDropper]],
#    2421     element: SchemaItem,
#    2422     **kwargs: Any,
#    2423 ) -> None:
#    2424     """run a DDL visitor.
#    2425
#    2426     This method is only here so that the MockConnection can change the
#    2427     options given to the visitor so that "checkfirst" is skipped.
#    2428
#    2429     """
# -> 2430     visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\sqlalchemy\sql\visitors.py:670, in ExternalTraversal.traverse_single(self, obj, **kw)
#     668 meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     669 if meth:
# --> 670     return meth(obj, **kw)
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\sqlalchemy\sql\ddl.py:963, in SchemaGenerator.visit_table(self, table, create_ok, include_foreign_key_constraints, _is_metadata_operation)
#     954 if not self.dialect.supports_alter:
#     955     # e.g., don't omit any foreign key constraints
#     956     include_foreign_key_constraints = None
#     958 CreateTable(
#     959     table,
#     960     include_foreign_key_constraints=(
#     961         include_foreign_key_constraints
#     962     ),
# --> 963 )._invoke_with(self.connection)
#     965 if hasattr(table, "indexes"):
#     966     for index in table.indexes:
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\sqlalchemy\sql\ddl.py:315, in ExecutableDDLElement._invoke_with(self, bind)
#     313 def _invoke_with(self, bind):
#     314     if self._should_execute(self.target, bind):
# --> 315         return bind.execute(self)
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\sqlalchemy\engine\base.py:1414, in Connection.execute(self, statement, parameters, execution_options)
#    1412     raise exc.ObjectNotExecutableError(statement) from err
#    1413 else:
# -> 1414     return meth(
#    1415         self,
#    1416         distilled_parameters,
#    1417         execution_options or NO_OPTIONS,
#    1418     )
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\sqlalchemy\sql\ddl.py:181, in ExecutableDDLElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     178 def _execute_on_connection(
#     179     self, connection, distilled_params, execution_options
#     180 ):
# --> 181     return connection._execute_ddl(
#     182         self, distilled_params, execution_options
#     183     )
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\sqlalchemy\engine\base.py:1526, in Connection._execute_ddl(self, ddl, distilled_parameters, execution_options)
#    1521 dialect = self.dialect
#    1523 compiled = ddl.compile(
#    1524     dialect=dialect, schema_translate_map=schema_translate_map
#    1525 )
# -> 1526 ret = self._execute_context(
#    1527     dialect,
#    1528     dialect.execution_ctx_cls._init_ddl,
#    1529     compiled,
#    1530     None,
#    1531     execution_options,
#    1532     compiled,
#    1533 )
#    1534 if self._has_events or self.engine._has_events:
#    1535     self.dispatch.after_execute(
#    1536         self,
#    1537         ddl,
#    (...)
#    1541         ret,
#    1542     )
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\sqlalchemy\engine\base.py:1842, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1837     return self._exec_insertmany_context(
#    1838         dialect,
#    1839         context,
#    1840     )
#    1841 else:
# -> 1842     return self._exec_single_context(
#    1843         dialect, context, statement, parameters
#    1844     )
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\sqlalchemy\engine\base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1980     result = context._setup_result_proxy()
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\sqlalchemy\engine\base.py:2326, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2324 elif should_wrap:
#    2325     assert sqlalchemy_exception is not None
# -> 2326     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2327 else:
#    2328     assert exc_info[1] is not None
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962                 break
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#    1969     self.dispatch.after_cursor_execute(
#    1970         self,
#    1971         cursor,
#    (...)
#    1975         context.executemany,
#    1976     )
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\sqlalchemy\engine\default.py:748, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     747 def do_execute(self, cursor, statement, parameters, context=None):
# --> 748     cursor.execute(statement, parameters)
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pymysql\cursors.py:158, in Cursor.execute(self, query, args)
#     154     pass
#     156 query = self.mogrify(query, args)
# --> 158 result = self._query(query)
#     159 self._executed = query
#     160 return result
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pymysql\cursors.py:325, in Cursor._query(self, q)
#     323 conn = self._get_db()
#     324 self._clear_result()
# --> 325 conn.query(q)
#     326 self._do_get_result()
#     327 return self.rowcount
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pymysql\connections.py:549, in Connection.query(self, sql, unbuffered)
#     547     sql = sql.encode(self.encoding, "surrogateescape")
#     548 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 549 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     550 return self._affected_rows
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pymysql\connections.py:779, in Connection._read_query_result(self, unbuffered)
#     777 else:
#     778     result = MySQLResult(self)
# --> 779     result.read()
#     780 self._result = result
#     781 if result.server_status is not None:
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pymysql\connections.py:1157, in MySQLResult.read(self)
#    1155 def read(self):
#    1156     try:
# -> 1157         first_packet = self.connection._read_packet()
#    1159         if first_packet.is_ok_packet():
#    1160             self._read_ok_packet(first_packet)
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pymysql\connections.py:729, in Connection._read_packet(self, packet_type)
#     727     if self._result is not None and self._result.unbuffered_active is True:
#     728         self._result.unbuffered_active = False
# --> 729     packet.raise_for_error()
#     730 return packet
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File c:\Users\Windows 10\Documents\proyecto_final_Daniel\.final\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# ProgrammingError: (pymysql.err.ProgrammingError) (1166, "Incorrect column name 'Factura _o_Recibo '")
# [SQL:
# CREATE TABLE nombre_tabla (
# 	`Codigo_Cuenta` BIGINT,
# 	`Cliente` TEXT,
# 	`Descripcion_Producto` TEXT,
# 	`Retencion` TEXT,
# 	`Bien_o_Servicio` TEXT,
# 	`Factura _o_Recibo ` TEXT,
# 	`Total_Pagar` TEXT,
# 	`Impuesto ` TEXT,
# 	`Total_Libre ` TEXT,
# 	`Fecha_Estm_Pago` TEXT,
# 	tipo_cuenta TEXT
# )
#
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
! git fetch
! git merge
! git add .
! git commit -m "leyendo datos2"
! git push
# Out:
# Already up to date.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
