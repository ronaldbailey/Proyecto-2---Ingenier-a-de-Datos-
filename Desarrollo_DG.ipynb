# %%
print("hola mundo")
# Out:
# hola mundo

# %%
! git add .
# Out:
# warning: in the working copy of 'Desarrollo_DG.ipynb', LF will be replaced by CRLF the next time Git touches it

# %%
! git commit -m "primer commit DG"
! git push
# Out:
# [main 8475868] primer commit DG
#  1 file changed, 23 insertions(+), 7 deletions(-)
# remote: Resolving deltas:   0% (0/2)
# remote: Resolving deltas:  50% (1/2)
# remote: Resolving deltas: 100% (2/2)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/ronaldbailey/Proyecto-2---Ingenier-a-de-Datos-.git
#    892573c..8475868  main -> main

# %% [markdown]
# ## Instalando bibliotecas necesarias

# %%
! pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (1.24.2)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: six>=1.5 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install boto3
# Out:
# Requirement already satisfied: boto3 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (1.26.109)
# Requirement already satisfied: botocore<1.30.0,>=1.29.109 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from boto3) (1.29.109)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from boto3) (0.6.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from botocore<1.30.0,>=1.29.109->boto3) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from botocore<1.30.0,>=1.29.109->boto3) (1.26.15)
# Requirement already satisfied: six>=1.5 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.30.0,>=1.29.109->boto3) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (2.9.6)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install configparser
# Out:
# Requirement already satisfied: configparser in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (5.3.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! git fetch
! git merge
! git add .
! git commit -m "formato readme"
! git push
# Out:
# Already up to date.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
# !pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (1.0.3)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (2.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from sqlalchemy) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from sqlalchemy) (2.0.2)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from openpyxl) (1.1.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\windows 10\documents\proyecto_final_daniel\.final\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Importando bibliotecas

# %%
import pandas as pd
import numpy as np
import boto3
import psycopg2
import configparser
import matplotlib.pyplot as plt

# %%
DB_USER="admincuentas2"
DB_NAME="cuentas"
DB_PASSWORD="cuentas2admin2023"
DB_PORT=3306
DB_HOST="cuentas2.clptjw9nvvtu.us-east-1.rds.amazonaws.com"

mysql_driver = "mysql+pymysql://{}:{}@{}:{}/{}".format(DB_USER, DB_PASSWORD, DB_HOST, DB_PORT, DB_NAME)
print(mysql_driver)
# Out:
# mysql+pymysql://admincuentas2:cuentas2admin2023@cuentas2.clptjw9nvvtu.us-east-1.rds.amazonaws.com:3306/cuentas

# %%
data_tipo_transacciones = [
     {'id_tipo_transac': 85095, 'tipo_transaccion': 'Depóito'}, 
     {'id_tipo_transac': 85098, 'tipo_transaccion': 'Retiro'},
     {'id_tipo_transac': 85194, 'tipo_transaccion': 'Transferencia'},
     {'id_tipo_transac': 85133, 'tipo_transaccion': 'Pago Prestamo'}
]
print(data_tipo_transacciones)
# Out:
# [{'id_tipo_transac': 85095, 'tipo_transaccion': 'Depóito'}, {'id_tipo_transac': 85098, 'tipo_transaccion': 'Retiro'}, {'id_tipo_transac': 85194, 'tipo_transaccion': 'Transferencia'}, {'id_tipo_transac': 85133, 'tipo_transaccion': 'Pago Prestamo'}]

# %%
df_transaccion = pd.DataFrame(data_tipo_transacciones)
df_transaccion
# Out:
#    id_tipo_transac tipo_transaccion
# 0            85095          Depóito
# 1            85098           Retiro
# 2            85194    Transferencia
# 3            85133    Pago Prestamo

# %%
#response = df_transaccion.to_sql('tipo_transacciones',mysql_driver,index = False, if_exists ='append')
#response

# %%
! git fetch
! git merge
! git add .
! git commit -m "prueba de subida datos aws/mysql/visual"
! git push
# Out:
# Already up to date.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %% [markdown]
# # 1.Scope: Scope del Proyecto y descripción de fuentes de información

# %%
datos_crudos = pd.read_excel('../datos/cxc_cxp_bancos_el_rosario.xlsx')
#datos ingresados son reales, solo el numero de factura o recibo no se contaba con el, por lo que se coloco uno para posteriormente ya llenarlo con datos reales al usar el codigo. 
datos_crudos
# Out:
#     Codigo_Cuenta  Id_Cliente       Descripcion_Producto  Retencion
# 0               1           1                  manteles     0.00000  \
# 1               2           1                     polos     0.00000
# 2               3           2     150 gorras chiquimulja    0.00000
# 3               4           3     200 gorras P.P. Cabal     0.00000
# 4               5           4             polos blancas     0.00000
# 5               6           5          camisas formales     0.00000
# 6               7           6          camisas formales     0.00000
# 7               8           7         chumpas y camisas     0.00000
# 8               9           8                     polos     0.00000
# 9              10           9          filipinas negras     0.00000
# 10             11          10                     polos     0.00000
# 11             12          11                    gorras     0.00000
# 12             13          12                     polos     0.00000
# 13             14          13  confeccion polos servicio  123.00000
# 14             15          14           SERIGRAFIAS PNC    75.00000
# 15             16          14              BORDADOS PNC   406.25000
# 16             17          15          camisas formales     0.00000
# 17             18          16                     polos     0.00000
# 18             19          17                 uniformes     0.00000
# 19             20          18                     polos     0.00000
# 20             21          19         chumpas de diario     0.00000
# 21             22          20              13 columbias     0.00000
# 22             23          21     32 gorras papas pollo   120.00000
# 23             26          21     camisas mantenimiento     0.00000
# 24             28          21              26 columbias     0.00000
# 25             33          21  columbias tela importada     0.00000
# 26             34          21    columbias tela nacional    0.00000
# 27             47          21       gorras mantenimiento    0.00000
# 28             24          22                  playeras     0.00000
# 29             25          23          camisas formales     0.00000
# 30             27          24       Camisas manga larga   462.40000
# 31             29          24       camisas con broches     0.00000
# 32             35          24             camisas ADESA     0.00000
# 33             31          25       bordados en prendas     0.00000
# 34             41          25       Confeccion Columbias    0.00000
# 35             30          39     pedido completo abirl     0.00000
# 36             32          26         uniformes febrero     0.00000
# 37             36          27           camisas del sol     0.00000
# 38             37          28         1900 gorras marzo   450.36175
# 39             51          28  1900 gorras entrega abril    0.00000
# 40             38          29        300 gorras febrero    91.59900
# 41             39          30       camisas polo grises     0.00000
# 42             40          31            filipinas chef     0.00000
# 43             42          32                     gorras    0.00000
# 44             43          33        playeras y mochilas    0.00000
# 45             44          34             primer pedido     0.00000
# 46             46          34               pedido extra    0.00000
# 47             45          35         camisas columbias     0.00000
# 48             48          36                  bordados     0.00000
# 49             49          37             camisas extras    0.00000
# 50             50          38         camisas columbias   139.69651
#
#    Bien_o_Servicio      Factura_o_Recibo  Total_Pagar     Impuesto
# 0             Bien    64854FSEGS3182FS81       2890.0   332.477876  \
# 1             Bien    64854FSEGS3182FS92       3260.0   375.044248
# 2             Bien   64854FSEGS3182FS103       1650.0   189.823009
# 3             Bien   64854FSEGS3182FS114       2000.0   230.088496
# 4             Bien   64854FSEGS3182FS125        900.0   103.539823
# 5             Bien   64854FSEGS3182FS136       3105.0   357.212389
# 6             Bien   64854FSEGS3182FS147       1000.0   115.044248
# 7             Bien   64854FSEGS3182FS158       1845.0   212.256637
# 8             Bien   64854FSEGS3182FS169       1300.0   149.557522
# 9             Bien  64854FSEGS3182FS1710       3240.0   372.743363
# 10            Bien  64854FSEGS3182FS1811       1140.0   131.150442
# 11            Bien  64854FSEGS3182FS1912       3775.0   434.292035
# 12            Bien  64854FSEGS3182FS2013       1620.0   186.371681
# 13        Servicio  64854FSEGS3182FS2114       2460.0   283.008850
# 14        Servicio  64854FSEGS3182FS2215       1500.0   172.566372
# 15        Servicio  64854FSEGS3182FS2316       8125.0   934.734513
# 16            Bien  64854FSEGS3182FS2417        542.5    62.411504
# 17            Bien  64854FSEGS3182FS2518       1975.0   227.212389
# 18            Bien  64854FSEGS3182FS2619      23783.0  2736.097345
# 19            Bien  64854FSEGS3182FS2720       1012.5   116.482301
# 20            Bien  64854FSEGS3182FS2821       2907.5   334.491150
# 21            Bien  64854FSEGS3182FS2922       1755.0   201.902655
# 22            Bien  64854FSEGS3182FS3023       2400.0   276.106195
# 23            Bien  64854FSEGS3182FS3326       3025.0   348.008850
# 24            Bien  64854FSEGS3182FS3528       6370.0   732.831858
# 25            Bien  64854FSEGS3182FS4033       3574.0   411.168142
# 26            Bien  64854FSEGS3182FS4134       1470.0   169.115044
# 27            Bien  64854FSEGS3182FS5447        900.0   103.539823
# 28            Bien  64854FSEGS3182FS3124       1550.0   178.318584
# 29            Bien  64854FSEGS3182FS3225       6520.0   750.088496
# 30            Bien  64854FSEGS3182FS3427       9248.0  1063.929204
# 31            Bien  64854FSEGS3182FS3629       3776.0   434.407080
# 32            Bien  64854FSEGS3182FS4235       3750.0   431.415929
# 33        Servicio  64854FSEGS3182FS3831       5885.0   677.035398
# 34        Servicio  64854FSEGS3182FS4841      15960.0  1836.106195
# 35            Bien  64854FSEGS3182FS3730       9968.5  1146.818584
# 36            Bien  64854FSEGS3182FS3932      16068.0  1848.530973
# 37            Bien  64854FSEGS3182FS4336       6300.0   724.778761
# 38            Bien  64854FSEGS3182FS4437      28025.0  3224.115044
# 39            Bien  64854FSEGS3182FS5851      28025.0  3224.115044
# 40            Bien  64854FSEGS3182FS4538       5700.0   655.752212
# 41            Bien  64854FSEGS3182FS4639       4190.0   482.035398
# 42            Bien  64854FSEGS3182FS4740       2500.0   287.610619
# 43            Bien  64854FSEGS3182FS4942       4500.0   517.699115
# 44            Bien  64854FSEGS3182FS5043       7920.0   911.150442
# 45            Bien  64854FSEGS3182FS5144       3725.0   428.539823
# 46            Bien  64854FSEGS3182FS5346       3537.0   406.911504
# 47            Bien  64854FSEGS3182FS5245       5335.0   613.761062
# 48            Bien  64854FSEGS3182FS5548        884.0   101.699115
# 49            Bien  64854FSEGS3182FS5649        542.5    62.411504
# 50            Bien  64854FSEGS3182FS5750       8693.0  1000.079646
#
#      Total_Libre Fecha_Estm_Pago           tipo_cuenta
# 0    2557.522124      2023-04-15                 libre
# 1    2884.955752      2023-04-15                 libre
# 2    1460.176991      2023-04-12                 libre
# 3    1769.911504      2023-04-13                 libre
# 4     796.460177      2023-04-18                 libre
# 5    2747.787611      2023-04-15                 libre
# 6     884.955752      2023-04-15                 libre
# 7    1632.743363      2023-04-12                 libre
# 8    1150.442478      2023-04-13                 libre
# 9    2867.256637      2023-04-18                 libre
# 10   1008.849558      2023-04-15                 libre
# 11   3340.707965      2023-08-25                 libre
# 12   1433.628319      2023-04-13                 libre
# 13   2176.991150      2023-04-18                 libre
# 14   1327.433628      2023-04-15                 libre
# 15   7190.265487      2023-08-25                 libre
# 16    480.088496      2023-04-13                 libre
# 17   1747.787611      2023-04-18                 libre
# 18  21046.902655      2023-04-15                 libre
# 19    896.017699      2023-04-15                 libre
# 20   2573.008850      2023-04-12                 libre
# 21   1553.097345      2023-04-13                 libre
# 22   2123.893805      2023-04-18                 libre
# 23   2676.991150      2023-04-12                 libre
# 24   5637.168142      2023-04-18                 libre
# 25   3162.831858      2023-04-15  extrafinanciamiento
# 26   1300.884956      2023-08-25  extrafinanciamiento
# 27    796.460177      2023-04-15               capital
# 28   1371.681416      2023-04-15                 libre
# 29   5769.911504      2023-04-15                 libre
# 30   8184.070796      2023-04-13                 libre
# 31   3341.592920      2023-04-15                 libre
# 32   3318.584071      2023-04-13  extrafinanciamiento
# 33   5207.964602      2023-04-13  extrafinanciamiento
# 34  14123.893805      2023-04-13               capital
# 35   8821.681416      2023-08-25                 libre
# 36  14219.469027      2023-04-18  extrafinanciamiento
# 37   5575.221239      2023-04-07  extrafinanciamiento
# 38  24800.884956      2023-04-08  extrafinanciamiento
# 39  24800.884956      2023-04-23               capital
# 40   5044.247788      2023-04-01  extrafinanciamiento
# 41   3707.964602      2023-04-16  extrafinanciamiento
# 42   2212.389381      2023-08-25  extrafinanciamiento
# 43   3982.300885      2023-04-07               capital
# 44   7008.849558      2023-04-08               capital
# 45   3296.460177      2023-04-01               capital
# 46   3130.088496      2023-04-18               capital
# 47   4721.238938      2023-04-16               capital
# 48    782.300885      2023-08-25               capital
# 49    480.088496      2023-04-13               capital
# 50   7692.920354      2023-04-20               capital

# %%
datos_crudos_clientes = pd.read_csv('../datos/Clientes_Info.csv')
#datos ingresados son reales, solo el numero de factura o recibo no se contaba con el, por lo que se coloco uno para posteriormente ya llenarlo con datos reales al usar el codigo. 
datos_crudos_clientes
# Out:
#     Id_Cliente                    Cliente
# 0            1             Xenturi Global  \
# 1            1             Xenturi Global
# 2            2                     ALTSA
# 3            3                Indellantas
# 4            4                Bobalicius
# 5            5           Profesor Abraham
# 6            6       Colegio Santa Marta
# 7            7              interconsumo
# 8            8   colegio pequenos angeles
# 9            9             sennsa Studio
# 10          10                yummy food
# 11          11  Policia Militar 2 brigada
# 12          12                fricsergua
# 13          13                  El Rodeo
# 14          14                       UNBO
# 15          14                       UNBO
# 16          15       Servicios Manducare
# 17          16        Recursos del Golfo
# 18          17               Casa blanca
# 19          18             Hector Bistro
# 20          19               Arbol verde
# 21          20       Don Manuel Columbias
# 22          21              Pollo Campero
# 23          21              Pollo Campero
# 24          21              Pollo Campero
# 25          21              Pollo Campero
# 26          21              Pollo Campero
# 27          21              Pollo Campero
# 28          22                   Blessco
# 29          23     Cahabon escuela Arjona
# 30          24                Grupo Rolsa
# 31          24                Grupo Rolsa
# 32          24                Grupo Rolsa
# 33          25               David Guzman
# 34          25               David Guzman
# 35          39                     Trixo
# 36          26               La estancia
# 37          27       Transportes del Sol
# 38          28                      Z Gas
# 39          28                      Z Gas
# 40          29                       KIA
# 41          30            Eventos Shadai
# 42          31                Il Pecieri
# 43          32                   AMSTAFF
# 44          33                     ALOHA
# 45          34                     DAITOM
# 46          34                     DAITOM
# 47          35                     UPANA
# 48          36    General Safety Bordados
# 49          37                Agrosafari
# 50          38           Bejo Cancelacion
#
#                                        Direccion Vendedor_Asignado
# 0                        20 calle 22-21 zona 10             Ileana
# 1                        20 calle 22-21 zona 10             Ileana
# 2               Centro de negocios La paz zona 5            Manuel
# 3                           7 calle 13-4 zona 8             Manuel
# 4                         10 calle 25-13 zona 12           Shirley
# 5           sacatepequez 23 avenida 13-25 zona 1            Manuel
# 6                          3 avenida 6-04 zona 8         Jaqueline
# 7                          7 avenida 4-13 zona 9            Manuel
# 8                         5 avenida 14-36 zona 2         Jaqueline
# 9                          4 calle 3-45 zona 14            Shirley
# 10                          2 calle 7-85 zona 17           Shirley
# 11                       10 avenida 4-36 zona 5             Manuel
# 12                        9 avenida 14-36 zona 2           Shirley
# 13                              Geminis zona 10             Manuel
# 14                         17 calle 13-2 zona 19            Manuel
# 15                         17 calle 13-2 zona 19            Manuel
# 16                       12 avenida 14-36 zona 2         Jaqueline
# 17                       3 avenida 12-04 zona 10         Jaqueline
# 18                       6 avenida 10-54 zona 20            Ileana
# 19                         7 avenida 6-04 zona 4            Ileana
# 20                       4 avenida 11-04 zona 10         Jaqueline
# 21                       6 avenida 22-04 zona 10            Manuel
# 22             zona empresarial pradera zona 10          Jaqueline
# 23             zona empresarial pradera zona 10          Jaqueline
# 24             zona empresarial pradera zona 10          Jaqueline
# 25             zona empresarial pradera zona 10          Jaqueline
# 26             zona empresarial pradera zona 10          Jaqueline
# 27             zona empresarial pradera zona 10          Jaqueline
# 28                         20 calle 6-48 zona 15           Shirley
# 29                         18 calle 6-48 zona 10           Shirley
# 30                         16 calle 6-48 zona 10            Ileana
# 31                         16 calle 6-48 zona 10            Ileana
# 32                         16 calle 6-48 zona 10            Ileana
# 33                         14 calle 9-23 zona 18           Shirley
# 34                         14 calle 9-23 zona 18           Shirley
# 35                        20 calle 12-48 zona 12           Shirley
# 36                          5 calle 9-23 zona 20            Ileana
# 37                         18 calle 9-23 zona 21           Shirley
# 38                        9 avenida 4-13 zona 7             Manuel
# 39                        9 avenida 4-13 zona 7             Manuel
# 40                        12 avenida 6-43 zona 8            Manuel
# 41                        19 avenida 8-18 zona 9            Ileana
# 42                         6 avenida 3-1 zona 10            Ileana
# 43                           14calle 9-23 zona 9            Ileana
# 44                          16 calle 6-63 zona 9            Manuel
# 45                          13 calle 4-53 zona 9           Shirley
# 46                          13 calle 4-53 zona 9           Shirley
# 47                      15 avenida 10-57 zona 16         Jaqueline
# 48                       16 avenida 9-25 zona 13            Ileana
# 49     zona empresarial torre 2 pradera zona 10             Ileana
# 50  san lucas sacatepequez 3 avenida 4-12 zona 4            Ileana

# %%
! git fetch
! git merge
! git add .
! git commit -m "leyendo_datos4_finalfinal"
! git push
# Out:
# Already up to date.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %% [markdown]
# # 2.Exploración: Exploración de la data para definir el modelo de datos

# %%
datos_crudos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Codigo_Cuenta         51 non-null     int64
#  1   Id_Cliente            51 non-null     int64
#  2   Descripcion_Producto  51 non-null     object
#  3   Retencion             51 non-null     float64
#  4   Bien_o_Servicio       51 non-null     object
#  5   Factura_o_Recibo      51 non-null     object
#  6   Total_Pagar           51 non-null     float64
#  7   Impuesto              51 non-null     float64
#  8   Total_Libre           51 non-null     float64
#  9   Fecha_Estm_Pago       51 non-null     datetime64[ns]
#  10  tipo_cuenta           51 non-null     object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(4)
# memory usage: 4.5+ KB

# %%
datos_crudos_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id_Cliente         51 non-null     int64
#  1   Cliente            51 non-null     object
#  2   Direccion          51 non-null     object
#  3   Vendedor_Asignado  51 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.7+ KB

# %%
datos_crudos.describe()
# Out:
#        Codigo_Cuenta  Id_Cliente   Retencion   Total_Pagar     Impuesto
# count      51.000000   51.000000   51.000000     51.000000    51.000000  \
# mean       26.000000   20.294118   36.633476   5335.813725   613.854676
# min         1.000000    1.000000    0.000000    542.500000    62.411504
# 25%        13.500000   12.500000    0.000000   1635.000000   188.097345
# 50%        26.000000   21.000000    0.000000   3240.000000   372.743363
# 75%        38.500000   28.000000    0.000000   6092.500000   700.907080
# max        51.000000   39.000000  462.400000  28025.000000  3224.115044
# std        14.866069   10.634461  107.358785   6377.708909   733.718724
#
#         Total_Libre                Fecha_Estm_Pago
# count     51.000000                             51
# mean    4721.959049  2023-04-29 12:42:21.176470528
# min      480.088496            2023-04-01 00:00:00
# 25%     1446.902655            2023-04-13 00:00:00
# 50%     2867.256637            2023-04-15 00:00:00
# 75%     5391.592920            2023-04-18 00:00:00
# max    24800.884956            2023-08-25 00:00:00
# std     5643.990185                            NaN

# %%
datos_crudos.plot(kind = 'scatter', x = 'Fecha_Estm_Pago', y = 'Total_Pagar')

plt.show()

# %% [markdown]
# # 3.Modelo de datos: Deberá definer el modelo de datos que usará para su Proyecto ya sea un DW o un DL

# %% [markdown]
# ### podría ser más conveniente utilizar un Data Lake en lugar de un Data Warehouse por las siguientes razones:
#
# - Flexibilidad: Un Data Lake permite almacenar todo tipo de datos en su formato original, sin necesidad de transformarlos previamente. Esto significa que puede manejar una gran variedad de datos, incluyendo datos estructurados, no estructurados y semiestructurados. Además, el almacenamiento de datos en bruto permite que los datos puedan ser transformados y utilizados de diferentes maneras en el futuro.
#
# - Escalabilidad: El Data Lake es altamente escalable y puede manejar grandes cantidades de datos. Con el crecimiento de la cantidad de datos, el Data Lake puede aumentar la capacidad de almacenamiento de manera efectiva, sin requerir modificaciones significativas.
#
# - Costo: El Data Lake es más económico que el Data Warehouse, ya que se utiliza un almacenamiento de bajo costo como Hadoop Distributed File System (HDFS) o Amazon S3 para almacenar los datos, en lugar de utilizar una base de datos relacional costosa.
#
# - Análisis avanzado: El Data Lake permite aplicar técnicas de análisis avanzado como el machine learning y el procesamiento de lenguaje natural en los datos sin la necesidad de migrar o transformar los datos.

# %%
! git fetch
! git merge
! git add .
! git commit -m "respondiendo hasta la pregunta 3"
! git push
# Out:
# Already up to date.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %% [markdown]
# ## Transformacion de datos

# %%
clientes_limpios = datos_crudos_clientes.drop_duplicates().sort_values('Id_Cliente').reset_index(drop = True)
clientes_limpios
# Out:
#     Id_Cliente                    Cliente
# 0            1             Xenturi Global  \
# 1            2                     ALTSA
# 2            3                Indellantas
# 3            4                Bobalicius
# 4            5           Profesor Abraham
# 5            6       Colegio Santa Marta
# 6            7              interconsumo
# 7            8   colegio pequenos angeles
# 8            9             sennsa Studio
# 9           10                yummy food
# 10          11  Policia Militar 2 brigada
# 11          12                fricsergua
# 12          13                  El Rodeo
# 13          14                       UNBO
# 14          15       Servicios Manducare
# 15          16        Recursos del Golfo
# 16          17               Casa blanca
# 17          18             Hector Bistro
# 18          19               Arbol verde
# 19          20       Don Manuel Columbias
# 20          21              Pollo Campero
# 21          22                   Blessco
# 22          23     Cahabon escuela Arjona
# 23          24                Grupo Rolsa
# 24          25               David Guzman
# 25          26               La estancia
# 26          27       Transportes del Sol
# 27          28                      Z Gas
# 28          29                       KIA
# 29          30            Eventos Shadai
# 30          31                Il Pecieri
# 31          32                   AMSTAFF
# 32          33                     ALOHA
# 33          34                     DAITOM
# 34          35                     UPANA
# 35          36    General Safety Bordados
# 36          37                Agrosafari
# 37          38           Bejo Cancelacion
# 38          39                     Trixo
#
#                                        Direccion Vendedor_Asignado
# 0                        20 calle 22-21 zona 10             Ileana
# 1               Centro de negocios La paz zona 5            Manuel
# 2                           7 calle 13-4 zona 8             Manuel
# 3                         10 calle 25-13 zona 12           Shirley
# 4           sacatepequez 23 avenida 13-25 zona 1            Manuel
# 5                          3 avenida 6-04 zona 8         Jaqueline
# 6                          7 avenida 4-13 zona 9            Manuel
# 7                         5 avenida 14-36 zona 2         Jaqueline
# 8                          4 calle 3-45 zona 14            Shirley
# 9                           2 calle 7-85 zona 17           Shirley
# 10                       10 avenida 4-36 zona 5             Manuel
# 11                        9 avenida 14-36 zona 2           Shirley
# 12                              Geminis zona 10             Manuel
# 13                         17 calle 13-2 zona 19            Manuel
# 14                       12 avenida 14-36 zona 2         Jaqueline
# 15                       3 avenida 12-04 zona 10         Jaqueline
# 16                       6 avenida 10-54 zona 20            Ileana
# 17                         7 avenida 6-04 zona 4            Ileana
# 18                       4 avenida 11-04 zona 10         Jaqueline
# 19                       6 avenida 22-04 zona 10            Manuel
# 20             zona empresarial pradera zona 10          Jaqueline
# 21                         20 calle 6-48 zona 15           Shirley
# 22                         18 calle 6-48 zona 10           Shirley
# 23                         16 calle 6-48 zona 10            Ileana
# 24                         14 calle 9-23 zona 18           Shirley
# 25                          5 calle 9-23 zona 20            Ileana
# 26                         18 calle 9-23 zona 21           Shirley
# 27                        9 avenida 4-13 zona 7             Manuel
# 28                        12 avenida 6-43 zona 8            Manuel
# 29                        19 avenida 8-18 zona 9            Ileana
# 30                         6 avenida 3-1 zona 10            Ileana
# 31                           14calle 9-23 zona 9            Ileana
# 32                          16 calle 6-63 zona 9            Manuel
# 33                          13 calle 4-53 zona 9           Shirley
# 34                      15 avenida 10-57 zona 16         Jaqueline
# 35                       16 avenida 9-25 zona 13            Ileana
# 36     zona empresarial torre 2 pradera zona 10             Ileana
# 37  san lucas sacatepequez 3 avenida 4-12 zona 4            Ileana
# 38                        20 calle 12-48 zona 12           Shirley

# %%
! git fetch
! git merge
! git add .
! git commit -m "dejando definidas las preguntas"
! git push
# Out:
# Already up to date.
# warning: in the working copy of 'Desarrollo_DG.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main 892573c] dejando definidas las preguntas
#  1 file changed, 92 insertions(+), 2 deletions(-)
# remote: Resolving deltas:   0% (0/2)
# remote: Resolving deltas:  50% (1/2)
# remote: Resolving deltas: 100% (2/2)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/ronaldbailey/Proyecto-2---Ingenier-a-de-Datos-.git
#    1ddbfec..892573c  main -> main

# %% [markdown]
# # Proceso ETL

# %%
# Insertar los datos en la tabla MySQL
datos_crudos.to_sql(name='datos_cuentas', con=mysql_driver, if_exists='replace', index=False)
clientes_limpios.to_sql(name='datos_clientes', con=mysql_driver, if_exists='replace', index=False)
# Out:
# 39

# %%
# Leer la primera tabla
df1 = pd.read_sql_query("SELECT * FROM datos_cuentas", mysql_driver)

# Leer la segunda tabla
df2 = pd.read_sql_query("SELECT * FROM datos_clientes", mysql_driver)

nuevo_df = pd.merge(df1, df2, on="Id_Cliente")
nuevo_df
# Out:
#     Codigo_Cuenta  Id_Cliente       Descripcion_Producto  Retencion
# 0               1           1                  manteles     0.00000  \
# 1               2           1                     polos     0.00000
# 2               3           2     150 gorras chiquimulja    0.00000
# 3               4           3     200 gorras P.P. Cabal     0.00000
# 4               5           4             polos blancas     0.00000
# 5               6           5          camisas formales     0.00000
# 6               7           6          camisas formales     0.00000
# 7               8           7         chumpas y camisas     0.00000
# 8               9           8                     polos     0.00000
# 9              10           9          filipinas negras     0.00000
# 10             11          10                     polos     0.00000
# 11             12          11                    gorras     0.00000
# 12             13          12                     polos     0.00000
# 13             14          13  confeccion polos servicio  123.00000
# 14             15          14           SERIGRAFIAS PNC    75.00000
# 15             16          14              BORDADOS PNC   406.25000
# 16             17          15          camisas formales     0.00000
# 17             18          16                     polos     0.00000
# 18             19          17                 uniformes     0.00000
# 19             20          18                     polos     0.00000
# 20             21          19         chumpas de diario     0.00000
# 21             22          20              13 columbias     0.00000
# 22             23          21     32 gorras papas pollo   120.00000
# 23             26          21     camisas mantenimiento     0.00000
# 24             28          21              26 columbias     0.00000
# 25             33          21  columbias tela importada     0.00000
# 26             34          21    columbias tela nacional    0.00000
# 27             47          21       gorras mantenimiento    0.00000
# 28             24          22                  playeras     0.00000
# 29             25          23          camisas formales     0.00000
# 30             27          24       Camisas manga larga   462.40000
# 31             29          24       camisas con broches     0.00000
# 32             35          24             camisas ADESA     0.00000
# 33             31          25       bordados en prendas     0.00000
# 34             41          25       Confeccion Columbias    0.00000
# 35             30          39     pedido completo abirl     0.00000
# 36             32          26         uniformes febrero     0.00000
# 37             36          27           camisas del sol     0.00000
# 38             37          28         1900 gorras marzo   450.36175
# 39             51          28  1900 gorras entrega abril    0.00000
# 40             38          29        300 gorras febrero    91.59900
# 41             39          30       camisas polo grises     0.00000
# 42             40          31            filipinas chef     0.00000
# 43             42          32                     gorras    0.00000
# 44             43          33        playeras y mochilas    0.00000
# 45             44          34             primer pedido     0.00000
# 46             46          34               pedido extra    0.00000
# 47             45          35         camisas columbias     0.00000
# 48             48          36                  bordados     0.00000
# 49             49          37             camisas extras    0.00000
# 50             50          38         camisas columbias   139.69651
#
#    Bien_o_Servicio      Factura_o_Recibo  Total_Pagar     Impuesto
# 0             Bien    64854FSEGS3182FS81       2890.0   332.477876  \
# 1             Bien    64854FSEGS3182FS92       3260.0   375.044248
# 2             Bien   64854FSEGS3182FS103       1650.0   189.823009
# 3             Bien   64854FSEGS3182FS114       2000.0   230.088496
# 4             Bien   64854FSEGS3182FS125        900.0   103.539823
# 5             Bien   64854FSEGS3182FS136       3105.0   357.212389
# 6             Bien   64854FSEGS3182FS147       1000.0   115.044248
# 7             Bien   64854FSEGS3182FS158       1845.0   212.256637
# 8             Bien   64854FSEGS3182FS169       1300.0   149.557522
# 9             Bien  64854FSEGS3182FS1710       3240.0   372.743363
# 10            Bien  64854FSEGS3182FS1811       1140.0   131.150442
# 11            Bien  64854FSEGS3182FS1912       3775.0   434.292035
# 12            Bien  64854FSEGS3182FS2013       1620.0   186.371681
# 13        Servicio  64854FSEGS3182FS2114       2460.0   283.008850
# 14        Servicio  64854FSEGS3182FS2215       1500.0   172.566372
# 15        Servicio  64854FSEGS3182FS2316       8125.0   934.734513
# 16            Bien  64854FSEGS3182FS2417        542.5    62.411504
# 17            Bien  64854FSEGS3182FS2518       1975.0   227.212389
# 18            Bien  64854FSEGS3182FS2619      23783.0  2736.097345
# 19            Bien  64854FSEGS3182FS2720       1012.5   116.482301
# 20            Bien  64854FSEGS3182FS2821       2907.5   334.491150
# 21            Bien  64854FSEGS3182FS2922       1755.0   201.902655
# 22            Bien  64854FSEGS3182FS3023       2400.0   276.106195
# 23            Bien  64854FSEGS3182FS3326       3025.0   348.008850
# 24            Bien  64854FSEGS3182FS3528       6370.0   732.831858
# 25            Bien  64854FSEGS3182FS4033       3574.0   411.168142
# 26            Bien  64854FSEGS3182FS4134       1470.0   169.115044
# 27            Bien  64854FSEGS3182FS5447        900.0   103.539823
# 28            Bien  64854FSEGS3182FS3124       1550.0   178.318584
# 29            Bien  64854FSEGS3182FS3225       6520.0   750.088496
# 30            Bien  64854FSEGS3182FS3427       9248.0  1063.929204
# 31            Bien  64854FSEGS3182FS3629       3776.0   434.407080
# 32            Bien  64854FSEGS3182FS4235       3750.0   431.415929
# 33        Servicio  64854FSEGS3182FS3831       5885.0   677.035398
# 34        Servicio  64854FSEGS3182FS4841      15960.0  1836.106195
# 35            Bien  64854FSEGS3182FS3730       9968.5  1146.818584
# 36            Bien  64854FSEGS3182FS3932      16068.0  1848.530973
# 37            Bien  64854FSEGS3182FS4336       6300.0   724.778761
# 38            Bien  64854FSEGS3182FS4437      28025.0  3224.115044
# 39            Bien  64854FSEGS3182FS5851      28025.0  3224.115044
# 40            Bien  64854FSEGS3182FS4538       5700.0   655.752212
# 41            Bien  64854FSEGS3182FS4639       4190.0   482.035398
# 42            Bien  64854FSEGS3182FS4740       2500.0   287.610619
# 43            Bien  64854FSEGS3182FS4942       4500.0   517.699115
# 44            Bien  64854FSEGS3182FS5043       7920.0   911.150442
# 45            Bien  64854FSEGS3182FS5144       3725.0   428.539823
# 46            Bien  64854FSEGS3182FS5346       3537.0   406.911504
# 47            Bien  64854FSEGS3182FS5245       5335.0   613.761062
# 48            Bien  64854FSEGS3182FS5548        884.0   101.699115
# 49            Bien  64854FSEGS3182FS5649        542.5    62.411504
# 50            Bien  64854FSEGS3182FS5750       8693.0  1000.079646
#
#      Total_Libre Fecha_Estm_Pago           tipo_cuenta
# 0    2557.522124      2023-04-15                 libre  \
# 1    2884.955752      2023-04-15                 libre
# 2    1460.176991      2023-04-12                 libre
# 3    1769.911504      2023-04-13                 libre
# 4     796.460177      2023-04-18                 libre
# 5    2747.787611      2023-04-15                 libre
# 6     884.955752      2023-04-15                 libre
# 7    1632.743363      2023-04-12                 libre
# 8    1150.442478      2023-04-13                 libre
# 9    2867.256637      2023-04-18                 libre
# 10   1008.849558      2023-04-15                 libre
# 11   3340.707965      2023-08-25                 libre
# 12   1433.628319      2023-04-13                 libre
# 13   2176.991150      2023-04-18                 libre
# 14   1327.433628      2023-04-15                 libre
# 15   7190.265487      2023-08-25                 libre
# 16    480.088496      2023-04-13                 libre
# 17   1747.787611      2023-04-18                 libre
# 18  21046.902655      2023-04-15                 libre
# 19    896.017699      2023-04-15                 libre
# 20   2573.008850      2023-04-12                 libre
# 21   1553.097345      2023-04-13                 libre
# 22   2123.893805      2023-04-18                 libre
# 23   2676.991150      2023-04-12                 libre
# 24   5637.168142      2023-04-18                 libre
# 25   3162.831858      2023-04-15  extrafinanciamiento
# 26   1300.884956      2023-08-25  extrafinanciamiento
# 27    796.460177      2023-04-15               capital
# 28   1371.681416      2023-04-15                 libre
# 29   5769.911504      2023-04-15                 libre
# 30   8184.070796      2023-04-13                 libre
# 31   3341.592920      2023-04-15                 libre
# 32   3318.584071      2023-04-13  extrafinanciamiento
# 33   5207.964602      2023-04-13  extrafinanciamiento
# 34  14123.893805      2023-04-13               capital
# 35   8821.681416      2023-08-25                 libre
# 36  14219.469027      2023-04-18  extrafinanciamiento
# 37   5575.221239      2023-04-07  extrafinanciamiento
# 38  24800.884956      2023-04-08  extrafinanciamiento
# 39  24800.884956      2023-04-23               capital
# 40   5044.247788      2023-04-01  extrafinanciamiento
# 41   3707.964602      2023-04-16  extrafinanciamiento
# 42   2212.389381      2023-08-25  extrafinanciamiento
# 43   3982.300885      2023-04-07               capital
# 44   7008.849558      2023-04-08               capital
# 45   3296.460177      2023-04-01               capital
# 46   3130.088496      2023-04-18               capital
# 47   4721.238938      2023-04-16               capital
# 48    782.300885      2023-08-25               capital
# 49    480.088496      2023-04-13               capital
# 50   7692.920354      2023-04-20               capital
#
#                       Cliente                                     Direccion
# 0              Xenturi Global                       20 calle 22-21 zona 10   \
# 1              Xenturi Global                       20 calle 22-21 zona 10
# 2                      ALTSA               Centro de negocios La paz zona 5
# 3                 Indellantas                          7 calle 13-4 zona 8
# 4                 Bobalicius                         10 calle 25-13 zona 12
# 5            Profesor Abraham          sacatepequez 23 avenida 13-25 zona 1
# 6        Colegio Santa Marta                          3 avenida 6-04 zona 8
# 7               interconsumo                          7 avenida 4-13 zona 9
# 8    colegio pequenos angeles                        5 avenida 14-36 zona 2
# 9              sennsa Studio                          4 calle 3-45 zona 14
# 10                yummy food                           2 calle 7-85 zona 17
# 11  Policia Militar 2 brigada                       10 avenida 4-36 zona 5
# 12                fricsergua                         9 avenida 14-36 zona 2
# 13                  El Rodeo                               Geminis zona 10
# 14                       UNBO                         17 calle 13-2 zona 19
# 15                       UNBO                         17 calle 13-2 zona 19
# 16       Servicios Manducare                        12 avenida 14-36 zona 2
# 17        Recursos del Golfo                        3 avenida 12-04 zona 10
# 18               Casa blanca                        6 avenida 10-54 zona 20
# 19             Hector Bistro                          7 avenida 6-04 zona 4
# 20               Arbol verde                        4 avenida 11-04 zona 10
# 21       Don Manuel Columbias                       6 avenida 22-04 zona 10
# 22              Pollo Campero             zona empresarial pradera zona 10
# 23              Pollo Campero             zona empresarial pradera zona 10
# 24              Pollo Campero             zona empresarial pradera zona 10
# 25              Pollo Campero             zona empresarial pradera zona 10
# 26              Pollo Campero             zona empresarial pradera zona 10
# 27              Pollo Campero             zona empresarial pradera zona 10
# 28                   Blessco                          20 calle 6-48 zona 15
# 29     Cahabon escuela Arjona                         18 calle 6-48 zona 10
# 30                Grupo Rolsa                         16 calle 6-48 zona 10
# 31                Grupo Rolsa                         16 calle 6-48 zona 10
# 32                Grupo Rolsa                         16 calle 6-48 zona 10
# 33               David Guzman                         14 calle 9-23 zona 18
# 34               David Guzman                         14 calle 9-23 zona 18
# 35                     Trixo                         20 calle 12-48 zona 12
# 36               La estancia                           5 calle 9-23 zona 20
# 37       Transportes del Sol                          18 calle 9-23 zona 21
# 38                      Z Gas                        9 avenida 4-13 zona 7
# 39                      Z Gas                        9 avenida 4-13 zona 7
# 40                       KIA                         12 avenida 6-43 zona 8
# 41            Eventos Shadai                         19 avenida 8-18 zona 9
# 42                Il Pecieri                          6 avenida 3-1 zona 10
# 43                   AMSTAFF                            14calle 9-23 zona 9
# 44                     ALOHA                           16 calle 6-63 zona 9
# 45                     DAITOM                          13 calle 4-53 zona 9
# 46                     DAITOM                          13 calle 4-53 zona 9
# 47                     UPANA                       15 avenida 10-57 zona 16
# 48    General Safety Bordados                       16 avenida 9-25 zona 13
# 49                Agrosafari      zona empresarial torre 2 pradera zona 10
# 50           Bejo Cancelacion  san lucas sacatepequez 3 avenida 4-12 zona 4
#
#    Vendedor_Asignado
# 0             Ileana
# 1             Ileana
# 2             Manuel
# 3             Manuel
# 4            Shirley
# 5             Manuel
# 6          Jaqueline
# 7             Manuel
# 8          Jaqueline
# 9            Shirley
# 10           Shirley
# 11            Manuel
# 12           Shirley
# 13            Manuel
# 14            Manuel
# 15            Manuel
# 16         Jaqueline
# 17         Jaqueline
# 18            Ileana
# 19            Ileana
# 20         Jaqueline
# 21            Manuel
# 22         Jaqueline
# 23         Jaqueline
# 24         Jaqueline
# 25         Jaqueline
# 26         Jaqueline
# 27         Jaqueline
# 28           Shirley
# 29           Shirley
# 30            Ileana
# 31            Ileana
# 32            Ileana
# 33           Shirley
# 34           Shirley
# 35           Shirley
# 36            Ileana
# 37           Shirley
# 38            Manuel
# 39            Manuel
# 40            Manuel
# 41            Ileana
# 42            Ileana
# 43            Ileana
# 44            Manuel
# 45           Shirley
# 46           Shirley
# 47         Jaqueline
# 48            Ileana
# 49            Ileana
# 50            Ileana

# %%
nuevo_df.describe()
# Out:
#        Codigo_Cuenta  Id_Cliente   Retencion   Total_Pagar     Impuesto
# count      51.000000   51.000000   51.000000     51.000000    51.000000  \
# mean       26.000000   20.294118   36.633476   5335.813725   613.854676
# min         1.000000    1.000000    0.000000    542.500000    62.411504
# 25%        13.500000   12.500000    0.000000   1635.000000   188.097345
# 50%        26.000000   21.000000    0.000000   3240.000000   372.743363
# 75%        38.500000   28.000000    0.000000   6092.500000   700.907080
# max        51.000000   39.000000  462.400000  28025.000000  3224.115044
# std        14.866069   10.634461  107.358785   6377.708909   733.718724
#
#         Total_Libre                Fecha_Estm_Pago
# count     51.000000                             51
# mean    4721.959049  2023-04-29 12:42:21.176470528
# min      480.088496            2023-04-01 00:00:00
# 25%     1446.902655            2023-04-13 00:00:00
# 50%     2867.256637            2023-04-15 00:00:00
# 75%     5391.592920            2023-04-18 00:00:00
# max    24800.884956            2023-08-25 00:00:00
# std     5643.990185                            NaN

# %%
nuevo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Codigo_Cuenta         51 non-null     int64
#  1   Id_Cliente            51 non-null     int64
#  2   Descripcion_Producto  51 non-null     object
#  3   Retencion             51 non-null     float64
#  4   Bien_o_Servicio       51 non-null     object
#  5   Factura_o_Recibo      51 non-null     object
#  6   Total_Pagar           51 non-null     float64
#  7   Impuesto              51 non-null     float64
#  8   Total_Libre           51 non-null     float64
#  9   Fecha_Estm_Pago       51 non-null     datetime64[ns]
#  10  tipo_cuenta           51 non-null     object
#  11  Cliente               51 non-null     object
#  12  Direccion             51 non-null     object
#  13  Vendedor_Asignado     51 non-null     object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(7)
# memory usage: 5.7+ KB

# %%
nuevo_df.plot(kind = 'scatter', x = 'Fecha_Estm_Pago', y = 'Total_Pagar')

plt.show()

# %% [markdown]
# # 4.Procesamiento: deberá definer todos su Código como un conjunto de scripts en Python, los cuales extraigan, transofrmen y cargen la data.(adjunto)

# %% [markdown]
# # 5. Analitica: Deberá plantear al menos 5 preguntas de análisis que puedan ser resueltas con la estructura que definio.
#
# 1. con cuanto se podra contar para el pago de quincena y de fin de mes (planilla).
# 2. quien es el cliente que mas cuentas tiene abiertas y cuanto debe
# 3. Cual es la cuenta mas grande
# 4. que vendedor vendio mas, o cuanto vendio cada vendedor.
# 5. cuanto suma en cada tipo de cuenta

# %% [markdown]
# # 1. Con cuanto se podra contar para el pago de quincena y de fin de mes

# %%
df = nuevo_df
df['quincena'] = nuevo_df['Fecha_Estm_Pago'].apply(lambda x: 2 * (x.day // 15) + 1)
df_quincenas = df.groupby('quincena').sum('Total_Libre')
df_quincenas[['Total_Libre']]
# Out:
#             Total_Libre
# quincena
# 1          95752.654867
# 3         145067.256637

# %% [markdown]
# #### 1 es la primera quincena y el 3 es el pago esperado en fin de mes

# %% [markdown]
# # 2. quien es el cliente que mas cuentas tiene abiertas y cuanto es el total que debe

# %%
frecuencia_clientes = df['Id_Cliente'].value_counts()
id_cliente_mas_cuentas = frecuencia_clientes.idxmax()
df_cliente_mas_cuentas = df[df['Id_Cliente'] == id_cliente_mas_cuentas]

# Sumamos la columna 'Total_Pagar' para obtener el total que debe ese cliente
total_deuda_cliente_mas_cuentas = df_cliente_mas_cuentas['Total_Pagar'].sum()

# Imprimimos los resultados
print(f"El cliente con ID {id_cliente_mas_cuentas} es el que tiene más cuentas abiertas.")
print(f"El total que debe este cliente es de ${total_deuda_cliente_mas_cuentas}.")
print(f"El cliente con ID 21 es: {nuevo_df[nuevo_df.Id_Cliente == 21].Cliente}")
# Out:
# El cliente con ID 21 es el que tiene más cuentas abiertas.
# El total que debe este cliente es de $17739.0.
# El cliente con ID 21 es: 22    Pollo Campero
# 23    Pollo Campero
# 24    Pollo Campero
# 25    Pollo Campero
# 26    Pollo Campero
# 27    Pollo Campero
# Name: Cliente, dtype: object

# %% [markdown]
# # 3. Cual es la cuenta mas grande

# %%
cuenta_mas_grande = df['Total_Pagar'].nlargest(1)
print(f"La Cuenta mas grande es: {nuevo_df[nuevo_df.index == 38].Cliente} con un total a pagar de: {cuenta_mas_grande}")
# Out:
# La Cuenta mas grande es: 38    Z Gas
# Name: Cliente, dtype: object con un total a pagar de: 38    28025.0
# Name: Total_Pagar, dtype: float64

# %% [markdown]
# # 4. que vendedor vendio mas, o cuanto vendio cada vendedor.

# %%
# Agrupar los datos por vendedor y sumar las ventas totales
ventas_por_vendedor = df.groupby('Vendedor_Asignado')['Total_Pagar'].sum()

# Obtener el vendedor que vendió más
vendedor_top = ventas_por_vendedor.idxmax()

# Obtener el total de ventas de cada vendedor
print(ventas_por_vendedor)
print(f"el vendedor top es: {vendedor_top}")
# Out:
# Vendedor_Asignado
# Ileana       85097.0
# Jaqueline    30799.0
# Manuel       95885.0
# Shirley      60345.5
# Name: Total_Pagar, dtype: float64
# el vendedor top es: Manuel

# %% [markdown]
# # 5. cuanto suma en cada tipo de cuenta

# %%
# Agrupar los datos por cuenta y sumar las ventas totales
ventas_por_cuenta = df.groupby('tipo_cuenta')['Total_Pagar'].sum()


# Obtener el total de ventas de cada cuenta
print(ventas_por_cuenta)
# Out:
# tipo_cuenta
# capital                  80021.5
# extrafinanciamiento      77462.0
# libre                   114643.0
# Name: Total_Pagar, dtype: float64
